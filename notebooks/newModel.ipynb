# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score, root_mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

np.random.seed(20020906)

# %%
def readDataFrame(filename):
    # Create the train-test-split
    df = pd.read_csv(filename)
    X = df.drop(columns=["temp","device", "ts"]).astype(float)
    y = df["temp"]
    return train_test_split(X, y, test_size=0.33)

# %%
X_train, X_test, y_train, y_test = readDataFrame('../data/raw/data.csv')

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), root_mean_squared_error(y_test, y_pred)
# Out:
# (0.7846806774873045, 0.7245492496324684, 1.2543074545729738)

# %%
lr.coef_
# Out:
# array([-6.72000263e+00, -1.30396132e+00,  2.09073426e+00, -2.66164198e+01,
#         1.68539603e-02,  3.32512864e+01])

# %%
from xgboost import XGBRegressor

# %%
xgb = XGBRegressor(seed = 20020906)
xgb.fit(X_train, y_train)
y_pred = xgb.predict(X_test)
r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred), root_mean_squared_error(y_test, y_pred)
# Out:
# (0.9367781961312894, 0.33330645642671985, 0.6796666221318263)
