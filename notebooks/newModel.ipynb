# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error

# %%
def readDataFrame(filename):
    # Create the train-test-split
    df = pd.read_csv(filename)
    X = df.drop(columns=["temp","device", "ts"]).astype(float)
    y = df["temp"]
    return train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train, X_test, y_train, y_test = readDataFrame('../data/raw/data.csv')

# %%
norm = StandardScaler()
X_train = norm.fit_transform(X_train)
X_test = norm.transform(X_test)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred)
# Out:
# (0.782159210072251, 0.7282245539590813)

# %%
lr.coef_
# Out:
# array([-6.92577979e+00, -1.30229619e+00,  2.09471094e+00, -2.75695902e+01,
#         1.99678721e-02,  3.44116082e+01])

# %%
from xgboost import XGBRegressor

# %%
xgb = XGBRegressor()
xgb.fit(X_train, y_train)
y_pred = xgb.predict(X_test)
r2_score(y_test, y_pred), mean_absolute_error(y_test, y_pred)
# Out:
# (0.9351754965697009, 0.3363004097844029)
